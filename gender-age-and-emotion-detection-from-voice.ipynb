# %%
# IMPORT THE LIBRARIES
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, roc_curve, auc
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # ***Gender Detection***

# %%
# LOAD THE DATASET
df = pd.read_csv('../input/gender-age-and-emotion-detection-from-voice/cleaned_gender.csv')

# %%
# FIRST FIVE DATASET
df.head()
# Out:
#    Unnamed: 0  meanfreq        sd    median       Q25       Q75       IQR  \
# 0          66  0.133338  0.069304  0.107668  0.089192  0.195267  0.106075
# 1          84  0.137433  0.058518  0.112037  0.092841  0.200079  0.107238
# 2          85  0.142227  0.065447  0.112242  0.093455  0.202909  0.109455
# 3          87  0.133325  0.072849  0.113360  0.082861  0.203753  0.120892
# 4          88  0.130487  0.070407  0.113418  0.076098  0.196188  0.120089
#
#        skew       kurt    sp.ent  ...  centroid   meanfun    minfun    maxfun  \
# 0  3.043456  13.694173  0.929512  ...  0.133338  0.121968  0.047337  0.277457
# 1  2.807995  12.776650  0.911080  ...  0.137433  0.111204  0.047151  0.277457
# 2  2.380899   9.942833  0.936040  ...  0.142227  0.118711  0.047013  0.275862
# 3  1.904123   7.799218  0.958362  ...  0.133325  0.116200  0.047105  0.279070
# 4  1.820873   8.561101  0.969568  ...  0.130487  0.114802  0.047151  0.279070
#
#     meandom  mindom    maxdom   dfrange   modindx  label
# 0  0.822656     0.0  4.687500  4.687500  0.076296   male
# 1  1.313384     0.0  6.046875  6.046875  0.135811   male
# 2  0.593750     0.0  6.539062  6.539062  0.096102   male
# 3  0.424922     0.0  5.812500  5.812500  0.081880   male
# 4  0.198070     0.0  1.078125  1.078125  0.131579   male
#
# [5 rows x 22 columns]

# %%
# COLUMNS NAMES
df=df.drop([df.columns[0]],axis=1)
df.columns
# Out:
# Index(['meanfreq', 'sd', 'median', 'Q25', 'Q75', 'IQR', 'skew', 'kurt',
#        'sp.ent', 'sfm', 'mode', 'centroid', 'meanfun', 'minfun', 'maxfun',
#        'meandom', 'mindom', 'maxdom', 'dfrange', 'modindx', 'label'],
#       dtype='object')

# %%
# CHECK THE MISSING VALUES
print(df.isnull().sum())
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %%
df.shape
# Out:
# (4361, 21)

# %%
df.describe()
# Out:
#           meanfreq           sd       median          Q25          Q75  \
# count  4361.000000  4361.000000  4361.000000  4361.000000  4361.000000
# mean      0.186093     0.057006     0.190335     0.145796     0.230877
# std       0.019862     0.009515     0.026870     0.031776     0.018412
# min       0.130253     0.031227     0.107668     0.057482     0.177122
# 25%       0.172234     0.050947     0.171007     0.122285     0.218621
# 50%       0.184996     0.058363     0.191987     0.140107     0.232547
# 75%       0.199711     0.063295     0.210788     0.168432     0.244517
# max       0.241377     0.082588     0.257051     0.235086     0.270893
#
#                IQR         skew         kurt       sp.ent          sfm  \
# count  4361.000000  4361.000000  4361.000000  4361.000000  4361.000000
# mean      0.085081     1.971404     7.933659     0.915496     0.443468
# std       0.028191     0.579158     3.329032     0.025962     0.121583
# min       0.020521     0.550830     2.377435     0.838816     0.141281
# 25%       0.059621     1.546014     5.363785     0.898416     0.355402
# 50%       0.092520     1.917493     7.170027     0.918524     0.440672
# 75%       0.108387     2.371233     9.873117     0.934720     0.530726
# max       0.150842     3.600165    17.922685     0.973249     0.785258
#
#               mode     centroid      meanfun       minfun       maxfun  \
# count  4361.000000  4361.000000  4361.000000  4361.000000  4361.000000
# mean      0.185193     0.186093     0.130606     0.047334     0.277241
# std       0.055095     0.019862     0.016937     0.000405     0.002250
# min       0.002527     0.130253     0.093660     0.046921     0.271186
# 25%       0.135029     0.172234     0.118378     0.047013     0.275862
# 50%       0.192089     0.184996     0.126001     0.047198     0.277457
# 75%       0.227678     0.199711     0.139656     0.047525     0.279070
# max       0.280000     0.241377     0.178343     0.048632     0.279070
#
#            meandom       mindom       maxdom      dfrange      modindx
# count  4361.000000  4361.000000  4361.000000  4361.000000  4361.000000
# mean      0.944215     0.016252     7.105706     7.089454     0.101832
# std       0.398433     0.045230     2.963021     2.963914     0.037590
# min       0.071470     0.000000     0.375000     0.375000     0.005507
# 25%       0.641129     0.000000     5.109375     5.109375     0.074496
# 50%       0.900000     0.000000     6.515625     6.492188     0.097698
# 75%       1.192127     0.000000     9.140625     9.140625     0.126405
# max       2.102571     0.351562    15.210938    15.210938     0.208333

# %%
df.label.value_counts()
# Out:
# male      3343
# female    1018
# Name: label, dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4361 entries, 0 to 4360
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  4361 non-null   float64
#  1   sd        4361 non-null   float64
#  2   median    4361 non-null   float64
#  3   Q25       4361 non-null   float64
#  4   Q75       4361 non-null   float64
#  5   IQR       4361 non-null   float64
#  6   skew      4361 non-null   float64
#  7   kurt      4361 non-null   float64
#  8   sp.ent    4361 non-null   float64
#  9   sfm       4361 non-null   float64
#  10  mode      4361 non-null   float64
#  11  centroid  4361 non-null   float64
#  12  meanfun   4361 non-null   float64
#  13  minfun    4361 non-null   float64
#  14  maxfun    4361 non-null   float64
#  15  meandom   4361 non-null   float64
#  16  mindom    4361 non-null   float64
#  17  maxdom    4361 non-null   float64
#  18  dfrange   4361 non-null   float64
#  19  modindx   4361 non-null   float64
#  20  label     4361 non-null   object
# dtypes: float64(20), object(1)
# memory usage: 715.6+ KB
# None

# %%
# DICTONARY FUNCTION
dict = {'label':{'male':1,'female':0}}      
df.replace(dict,inplace = True)           
X = df.loc[:, df.columns != 'label']
y = df.loc[:,'label']

# %%
# CORRELATION
corr_matrix=df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr_matrix,
           annot=True,
           linewidths=0.5,
           fmt=".2f",
           cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
model_acc = []

# %%
svm_c = 1000
svm_gamma = 0.01

dtc_md = 5

rfc_M = 8
rfc_d = 8
rfc_m = 6

# %%
model_acc = []

# %%
SVM_model = SVC(C=svm_c, gamma=svm_gamma).fit(X_train, y_train)
train_acc = SVM_model.score(X_train, y_train)
test_acc = SVM_model.score(X_test, y_test)
m = 'SVM'
model_acc.append([m, train_acc, test_acc])

DTC_model = DecisionTreeClassifier(max_depth=dtc_md).fit(X_train, y_train)
train_acc = DTC_model.score(X_train, y_train)
test_acc = DTC_model.score(X_test, y_test)
m = 'Decision Tree Classifier'
model_acc.append([m, train_acc, test_acc])

RFC_model = RandomForestClassifier(n_estimators=rfc_M, max_features=rfc_d, max_depth=rfc_m, random_state=0).fit(X_train, y_train)
train_acc = RFC_model.score(X_train, y_train)
test_acc = RFC_model.score(X_test, y_test)
m = 'Random Forest Classifier'
model_acc.append([m, train_acc, test_acc])

# %%
print("Feature importance of Decision Tree Classifier: ")
np.array([X.columns.values.tolist(), list(DTC_model.feature_importances_)]).T
# Out:
# Feature importance of Decision Tree Classifier:
# array([['meanfreq', '0.0031012752141155674'],
#        ['sd', '0.04999173994353594'],
#        ['median', '0.005836893874503962'],
#        ['Q25', '0.06462562263191284'],
#        ['Q75', '0.0'],
#        ['IQR', '0.0028724851424786965'],
#        ['skew', '0.004934751579293491'],
#        ['kurt', '0.0'],
#        ['sp.ent', '0.0'],
#        ['sfm', '0.009320905009532074'],
#        ['mode', '0.004926598449493371'],
#        ['centroid', '0.0'],
#        ['meanfun', '0.8282405374542997'],
#        ['minfun', '0.0'],
#        ['maxfun', '0.0'],
#        ['meandom', '0.016421032310383093'],
#        ['mindom', '0.0'],
#        ['maxdom', '0.007332250116031068'],
#        ['dfrange', '0.002395908274420351'],
#        ['modindx', '0.0']], dtype='<U32')

# %%
importances = DTC_model.feature_importances_
indices = np.argsort(importances)
plt.figure(figsize=(12,8))
plt.barh(range(len(indices)), importances[indices], align='center')
plt.yticks(range(len(indices)), df.columns[indices])
plt.title('Feature Importance')
# Out:
# Text(0.5, 1.0, 'Feature Importance')

# %%
print("Feature importance of Random Forest Classifier: ")
np.array([X.columns.values.tolist(), list(RFC_model.feature_importances_)]).T
# Out:
# Feature importance of Random Forest Classifier:
# array([['meanfreq', '0.008343530542015072'],
#        ['sd', '0.14725663469352374'],
#        ['median', '0.013889005851399207'],
#        ['Q25', '0.09102770164347916'],
#        ['Q75', '0.007616625865976439'],
#        ['IQR', '0.09749690185555107'],
#        ['skew', '0.004504295099846328'],
#        ['kurt', '0.006195655187940843'],
#        ['sp.ent', '0.005634225306343693'],
#        ['sfm', '0.01095592687817634'],
#        ['mode', '0.016263495625438877'],
#        ['centroid', '0.01047411442791782'],
#        ['meanfun', '0.5479934767663581'],
#        ['minfun', '0.0009644261490419477'],
#        ['maxfun', '0.0036366606081657572'],
#        ['meandom', '0.008656044731939979'],
#        ['mindom', '0.0007048362865788565'],
#        ['maxdom', '0.006909668259038644'],
#        ['dfrange', '0.006072308969297721'],
#        ['modindx', '0.005404465251970533']], dtype='<U32')

# %%
importances = RFC_model.feature_importances_
indices = np.argsort(importances)
plt.figure(figsize=(12,8))
plt.barh(range(len(indices)), importances[indices], align='center')
plt.yticks(range(len(indices)), df.columns[indices])
plt.title('Feature Importance')
# Out:
# Text(0.5, 1.0, 'Feature Importance')

# %%
result = pd.DataFrame(model_acc, columns=['Model', 'Training Accuracy', 'Validation Accuracy'])
result[['Model', 'Training Accuracy', 'Validation Accuracy']]
# Out:
#                       Model  Training Accuracy  Validation Accuracy
# 0                       SVM           0.935168             0.937672
# 1  Decision Tree Classifier           0.953517             0.934922
# 2  Random Forest Classifier           0.958410             0.939505

# %%
df_new = df[['meanfun', 'sd', 'Q25', 'IQR','mode','median','label']]
df_new.head()
# Out:
#     meanfun        sd       Q25       IQR      mode    median  label
# 0  0.121968  0.069304  0.089192  0.106075  0.086962  0.107668      1
# 1  0.111204  0.058518  0.092841  0.107238  0.101332  0.112037      1
# 2  0.118711  0.065447  0.093455  0.109455  0.106545  0.112242      1
# 3  0.116200  0.072849  0.082861  0.120892  0.108583  0.113360      1
# 4  0.114802  0.070407  0.076098  0.120089  0.101534  0.113418      1

# %%
X = df_new.loc[:, df_new.columns != 'label']
y = df_new.loc[:,'label']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
feat_rf = RandomForestClassifier(n_estimators=100, max_depth=50, random_state=0)
feat_his = feat_rf.fit(X_train,y_train)

# %%
print(feat_his.score(X_train,y_train))
print(feat_his.score(X_test,y_test))
# Out:
# 1.0
# 0.9376718606782768

# %%
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.pipeline import make_pipeline
from sklearn.svm import LinearSVC

anova_filter = SelectKBest(f_classif, k=6)
clf = RandomForestClassifier(n_estimators=rfc_M, max_features=6, max_depth=rfc_m, random_state=0)
anova_svm = make_pipeline(anova_filter, clf)
anova_svm.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('selectkbest', SelectKBest(k=6)),
#                 ('randomforestclassifier',
#                  RandomForestClassifier(max_depth=6, max_features=6,
#                                         n_estimators=8, random_state=0))])

# %%
print(anova_svm.score(X_train,y_train))
print(anova_svm.score(X_test,y_test))
# Out:
# 0.9617737003058104
# 0.9303391384051329

# %% [markdown]
# # ***Age Detection***

# %%
df = pd.read_csv('../input/gender-age-and-emotion-detection-from-voice/cleaned_age.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  meanfreq        sd    median       Q25       Q75  \
# 0          66            67  0.133338  0.069304  0.107668  0.089192  0.195267
# 1          84            85  0.137433  0.058518  0.112037  0.092841  0.200079
# 2          85            86  0.142227  0.065447  0.112242  0.093455  0.202909
# 3          87            88  0.133325  0.072849  0.113360  0.082861  0.203753
# 4          88            89  0.130487  0.070407  0.113418  0.076098  0.196188
#
#         IQR      skew       kurt  ...  centroid   meanfun    minfun    maxfun  \
# 0  0.106075  3.043456  13.694173  ...  0.133338  0.121968  0.047337  0.277457
# 1  0.107238  2.807995  12.776650  ...  0.137433  0.111204  0.047151  0.277457
# 2  0.109455  2.380899   9.942833  ...  0.142227  0.118711  0.047013  0.275862
# 3  0.120892  1.904123   7.799218  ...  0.133325  0.116200  0.047105  0.279070
# 4  0.120089  1.820873   8.561101  ...  0.130487  0.114802  0.047151  0.279070
#
#     meandom  mindom    maxdom   dfrange   modindx    label
# 0  0.822656     0.0  4.687500  4.687500  0.076296    young
# 1  1.313384     0.0  6.046875  6.046875  0.135811    young
# 2  0.593750     0.0  6.539062  6.539062  0.096102  matured
# 3  0.424922     0.0  5.812500  5.812500  0.081880    young
# 4  0.198070     0.0  1.078125  1.078125  0.131579  matured
#
# [5 rows x 23 columns]

# %%
df=df.drop([df.columns[0], df.columns[1]],axis=1)
df.columns
# Out:
# Index(['meanfreq', 'sd', 'median', 'Q25', 'Q75', 'IQR', 'skew', 'kurt',
#        'sp.ent', 'sfm', 'mode', 'centroid', 'meanfun', 'minfun', 'maxfun',
#        'meandom', 'mindom', 'maxdom', 'dfrange', 'modindx', 'label'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %%
df.shape
# Out:
# (4361, 21)

# %%
df.describe()
# Out:
#           meanfreq           sd       median          Q25          Q75  \
# count  4361.000000  4361.000000  4361.000000  4361.000000  4361.000000
# mean      0.186093     0.057006     0.190335     0.145796     0.230877
# std       0.019862     0.009515     0.026870     0.031776     0.018412
# min       0.130253     0.031227     0.107668     0.057482     0.177122
# 25%       0.172234     0.050947     0.171007     0.122285     0.218621
# 50%       0.184996     0.058363     0.191987     0.140107     0.232547
# 75%       0.199711     0.063295     0.210788     0.168432     0.244517
# max       0.241377     0.082588     0.257051     0.235086     0.270893
#
#                IQR         skew         kurt       sp.ent          sfm  \
# count  4361.000000  4361.000000  4361.000000  4361.000000  4361.000000
# mean      0.085081     1.971404     7.933659     0.915496     0.443468
# std       0.028191     0.579158     3.329032     0.025962     0.121583
# min       0.020521     0.550830     2.377435     0.838816     0.141281
# 25%       0.059621     1.546014     5.363785     0.898416     0.355402
# 50%       0.092520     1.917493     7.170027     0.918524     0.440672
# 75%       0.108387     2.371233     9.873117     0.934720     0.530726
# max       0.150842     3.600165    17.922685     0.973249     0.785258
#
#               mode     centroid      meanfun       minfun       maxfun  \
# count  4361.000000  4361.000000  4361.000000  4361.000000  4361.000000
# mean      0.185193     0.186093     0.130606     0.047334     0.277241
# std       0.055095     0.019862     0.016937     0.000405     0.002250
# min       0.002527     0.130253     0.093660     0.046921     0.271186
# 25%       0.135029     0.172234     0.118378     0.047013     0.275862
# 50%       0.192089     0.184996     0.126001     0.047198     0.277457
# 75%       0.227678     0.199711     0.139656     0.047525     0.279070
# max       0.280000     0.241377     0.178343     0.048632     0.279070
#
#            meandom       mindom       maxdom      dfrange      modindx
# count  4361.000000  4361.000000  4361.000000  4361.000000  4361.000000
# mean      0.944215     0.016252     7.105706     7.089454     0.101832
# std       0.398433     0.045230     2.963021     2.963914     0.037590
# min       0.071470     0.000000     0.375000     0.375000     0.005507
# 25%       0.641129     0.000000     5.109375     5.109375     0.074496
# 50%       0.900000     0.000000     6.515625     6.492188     0.097698
# 75%       1.192127     0.000000     9.140625     9.140625     0.126405
# max       2.102571     0.351562    15.210938    15.210938     0.208333

# %%
df.label.value_counts()
# Out:
# matured    1983
# young      1816
# old         562
# Name: label, dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4361 entries, 0 to 4360
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  4361 non-null   float64
#  1   sd        4361 non-null   float64
#  2   median    4361 non-null   float64
#  3   Q25       4361 non-null   float64
#  4   Q75       4361 non-null   float64
#  5   IQR       4361 non-null   float64
#  6   skew      4361 non-null   float64
#  7   kurt      4361 non-null   float64
#  8   sp.ent    4361 non-null   float64
#  9   sfm       4361 non-null   float64
#  10  mode      4361 non-null   float64
#  11  centroid  4361 non-null   float64
#  12  meanfun   4361 non-null   float64
#  13  minfun    4361 non-null   float64
#  14  maxfun    4361 non-null   float64
#  15  meandom   4361 non-null   float64
#  16  mindom    4361 non-null   float64
#  17  maxdom    4361 non-null   float64
#  18  dfrange   4361 non-null   float64
#  19  modindx   4361 non-null   float64
#  20  label     4361 non-null   object
# dtypes: float64(20), object(1)
# memory usage: 715.6+ KB
# None

# %%
dict = {'label':{'old':2,'matured':1,'young':0}}      
df.replace(dict,inplace = True)           
X = df.loc[:, df.columns != 'label']
y = df.loc[:,'label']

# %%
corr_matrix=df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr_matrix,
           annot=True,
           linewidths=0.5,
           fmt=".2f",
           cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
model_acc = []

# %%
svm_c = 10
svm_gamma = 0.1

dtc_md = 8

rfc_M = 14
rfc_d = 14
rfc_m = 16

# %%
SVM_model = SVC(C=svm_c, gamma=svm_gamma).fit(X_train, y_train)
train_acc = SVM_model.score(X_train, y_train)
test_acc = SVM_model.score(X_test, y_test)
m = 'SVM'
model_acc.append([m, train_acc, test_acc])

DTC_model = DecisionTreeClassifier(max_depth=dtc_md).fit(X_train, y_train)
train_acc = DTC_model.score(X_train, y_train)
test_acc = DTC_model.score(X_test, y_test)
m = 'Decision Tree Classifier'
model_acc.append([m, train_acc, test_acc])

RFC_model = RandomForestClassifier(n_estimators=rfc_M, max_features=rfc_d, max_depth=rfc_m, random_state=0).fit(X_train, y_train)
train_acc = RFC_model.score(X_train, y_train)
test_acc = RFC_model.score(X_test, y_test)
m = 'Random Forest Classifier'
model_acc.append([m, train_acc, test_acc])

# %%
print("Feature importance: ")
np.array([X.columns.values.tolist(), list(DTC_model.feature_importances_)]).T
# Out:
# Feature importance:
# array([['meanfreq', '0.023580466913734513'],
#        ['sd', '0.041322717919732264'],
#        ['median', '0.03298001167940346'],
#        ['Q25', '0.08125983259167671'],
#        ['Q75', '0.08193020477660047'],
#        ['IQR', '0.046497883694833674'],
#        ['skew', '0.04420651089765578'],
#        ['kurt', '0.019797391950795756'],
#        ['sp.ent', '0.0422181527343618'],
#        ['sfm', '0.1633573107434196'],
#        ['mode', '0.07079667008915207'],
#        ['centroid', '0.009326652497238304'],
#        ['meanfun', '0.07632672404190947'],
#        ['minfun', '0.03727872421272911'],
#        ['maxfun', '0.0074239143582162'],
#        ['meandom', '0.08136155451859817'],
#        ['mindom', '0.005832233515967901'],
#        ['maxdom', '0.020384699802538347'],
#        ['dfrange', '0.048926140350024516'],
#        ['modindx', '0.06519220271141195']], dtype='<U32')

# %%
importances = DTC_model.feature_importances_
indices = np.argsort(importances)
plt.figure(figsize=(12,8))
plt.barh(range(len(indices)), importances[indices], align='center')
plt.yticks(range(len(indices)), df.columns[indices])
plt.title('Feature Importance')
# Out:
# Text(0.5, 1.0, 'Feature Importance')

# %%
print("Feature importance: ")
np.array([X.columns.values.tolist(), list(RFC_model.feature_importances_)]).T
# Out:
# Feature importance:
# array([['meanfreq', '0.030450682883483005'],
#        ['sd', '0.07361541798235484'],
#        ['median', '0.04688410597586191'],
#        ['Q25', '0.06487433260263809'],
#        ['Q75', '0.04626146196261762'],
#        ['IQR', '0.0540329783802101'],
#        ['skew', '0.04508273999985586'],
#        ['kurt', '0.04369983101949494'],
#        ['sp.ent', '0.057461716220009375'],
#        ['sfm', '0.07392284322901654'],
#        ['mode', '0.059930555857985415'],
#        ['centroid', '0.03300121808632523'],
#        ['meanfun', '0.0722364578702301'],
#        ['minfun', '0.0430582196591403'],
#        ['maxfun', '0.01596220353432269'],
#        ['meandom', '0.0666166979897387'],
#        ['mindom', '0.009036318543593633'],
#        ['maxdom', '0.05035178363688155'],
#        ['dfrange', '0.05185205716335701'],
#        ['modindx', '0.06166837740288309']], dtype='<U32')

# %%
importances = RFC_model.feature_importances_
indices = np.argsort(importances)
plt.figure(figsize=(12,8))
plt.barh(range(len(indices)), importances[indices], align='center')
plt.yticks(range(len(indices)), df.columns[indices])
plt.title('Feature Importance')
# Out:
# Text(0.5, 1.0, 'Feature Importance')

# %%
result = pd.DataFrame(model_acc, columns=['Model', 'Training Accuracy', 'Validation Accuracy'])
result[['Model', 'Training Accuracy', 'Validation Accuracy']]
# Out:
#                       Model  Training Accuracy  Validation Accuracy
# 0                       SVM           0.547401             0.500458
# 1  Decision Tree Classifier           0.661468             0.541705
# 2  Random Forest Classifier           0.982263             0.586618

# %% [markdown]
# # ***Emotion Detection***

# %%
df = pd.read_csv('../input/gender-age-and-emotion-detection-from-voice/cleaned_emotion.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  X  meanfreq        sd    median       Q25  \
# 0           0             1  1  0.181338  0.060495  0.187476  0.126197
# 1           1             2  2  0.186897  0.062260  0.195070  0.130847
# 2           2             3  3  0.189102  0.062901  0.204945  0.131422
# 3           4             5  5  0.183036  0.060051  0.174115  0.129949
# 4           5             6  6  0.168793  0.057910  0.156266  0.116783
#
#         Q75       IQR      skew  ...  centroid   meanfun    minfun    maxfun  \
# 0  0.233586  0.107389  0.869088  ...  0.181338  0.137742  0.023022  0.271186
# 1  0.243987  0.113140  1.191767  ...  0.186897  0.121811  0.018412  0.271186
# 2  0.249978  0.118556  1.312690  ...  0.189102  0.123758  0.083333  0.262295
# 3  0.236967  0.107017  1.096409  ...  0.183036  0.128469  0.044693  0.258065
# 4  0.216326  0.099543  1.386837  ...  0.168793  0.109720  0.022472  0.235294
#
#     meandom    mindom    maxdom   dfrange   modindx  label
# 0  0.777344  0.085938  6.226562  6.140625  0.116586    sad
# 1  0.930339  0.085938  4.000000  3.914062  0.144983    sad
# 2  0.332386  0.085938  0.625000  0.539062  0.334783    sad
# 3  1.012019  0.085938  5.468750  5.382812  0.304910    sad
# 4  0.228795  0.093750  0.750000  0.656250  0.306777    sad
#
# [5 rows x 24 columns]

# %%
df=df.drop([df.columns[0], df.columns[1], df.columns[2]],axis=1)
df.columns
# Out:
# Index(['meanfreq', 'sd', 'median', 'Q25', 'Q75', 'IQR', 'skew', 'kurt',
#        'sp.ent', 'sfm', 'mode', 'centroid', 'meanfun', 'minfun', 'maxfun',
#        'meandom', 'mindom', 'maxdom', 'dfrange', 'modindx', 'label'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %%
df.shape
# Out:
# (909, 21)

# %%
df.describe()
# Out:
#          meanfreq          sd      median         Q25         Q75         IQR  \
# count  909.000000  909.000000  909.000000  909.000000  909.000000  909.000000
# mean     0.206170    0.051275    0.212524    0.177508    0.244574    0.067065
# std      0.023133    0.014841    0.027557    0.038010    0.017223    0.029831
# min      0.138892    0.024114    0.139472    0.046111    0.193367    0.020098
# 25%      0.185884    0.037961    0.191591    0.146098    0.232371    0.042470
# 50%      0.207456    0.049979    0.216077    0.184609    0.245731    0.057073
# 75%      0.226357    0.062497    0.233591    0.211461    0.259418    0.092380
# max      0.250264    0.100239    0.264487    0.250455    0.274048    0.173421
#
#              skew        kurt      sp.ent         sfm        mode    centroid  \
# count  909.000000  909.000000  909.000000  909.000000  909.000000  909.000000
# mean     2.095407    8.336008    0.884311    0.298569    0.220830    0.206170
# std      0.614903    3.511599    0.036912    0.134277    0.047916    0.023133
# min      0.681156    2.657216    0.783243    0.074134    0.084523    0.138892
# 25%      1.628812    5.531592    0.854904    0.182142    0.195945    0.185884
# 50%      2.068654    7.563524    0.885243    0.281802    0.231820    0.207456
# 75%      2.504630   10.571021    0.917343    0.405891    0.263500    0.226357
# max      3.800316   18.224444    0.959177    0.710205    0.280000    0.250264
#
#           meanfun      minfun      maxfun     meandom      mindom      maxdom  \
# count  909.000000  909.000000  909.000000  909.000000  909.000000  909.000000
# mean     0.166384    0.032167    0.259240    0.791625    0.129787    4.224534
# std      0.032946    0.018036    0.018766    0.318400    0.101413    1.966856
# min      0.074660    0.015640    0.192771    0.107319    0.000000    0.234375
# 25%      0.141497    0.018328    0.250000    0.544271    0.000000    2.960938
# 50%      0.173804    0.024768    0.266667    0.765625    0.148438    4.500000
# 75%      0.192616    0.040921    0.275862    1.005729    0.210938    5.875000
# max      0.228604    0.086957    0.275862    1.724888    0.500000    6.992188
#
#           dfrange     modindx
# count  909.000000  909.000000
# mean     4.094747    0.204235
# std      1.958441    0.070437
# min      0.085938    0.009846
# 25%      2.781250    0.151972
# 50%      4.367188    0.194397
# 75%      5.734375    0.245702
# max      6.992188    0.401399

# %%
df.label.value_counts()
# Out:
# sad      314
# angry    302
# happy    293
# Name: label, dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 909 entries, 0 to 908
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  909 non-null    float64
#  1   sd        909 non-null    float64
#  2   median    909 non-null    float64
#  3   Q25       909 non-null    float64
#  4   Q75       909 non-null    float64
#  5   IQR       909 non-null    float64
#  6   skew      909 non-null    float64
#  7   kurt      909 non-null    float64
#  8   sp.ent    909 non-null    float64
#  9   sfm       909 non-null    float64
#  10  mode      909 non-null    float64
#  11  centroid  909 non-null    float64
#  12  meanfun   909 non-null    float64
#  13  minfun    909 non-null    float64
#  14  maxfun    909 non-null    float64
#  15  meandom   909 non-null    float64
#  16  mindom    909 non-null    float64
#  17  maxdom    909 non-null    float64
#  18  dfrange   909 non-null    float64
#  19  modindx   909 non-null    float64
#  20  label     909 non-null    object
# dtypes: float64(20), object(1)
# memory usage: 149.3+ KB
# None

# %%
dict = {'label':{'sad':0,'angry':1, 'happy':2}}      
df.replace(dict,inplace = True)           
X = df.loc[:, df.columns != 'label']
y = df.loc[:,'label']

# %%
corr_matrix=df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr_matrix,
           annot=True,
           linewidths=0.5,
           fmt=".2f",
           cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
model_acc = []

# %%
svm_c = 1000
svm_gamma = 0.01

dtc_md = 4

rfc_M = 14
rfc_d = 8
rfc_m = 16

# %%
SVM_model = SVC(C=svm_c, gamma=svm_gamma).fit(X_train, y_train)
train_acc = SVM_model.score(X_train, y_train)
test_acc = SVM_model.score(X_test, y_test)
m = 'SVM'
model_acc.append([m, train_acc, test_acc])

DTC_model = DecisionTreeClassifier(max_depth=dtc_md).fit(X_train, y_train)
train_acc = DTC_model.score(X_train, y_train)
test_acc = DTC_model.score(X_test, y_test)
m = 'Decision Tree Classifier'
model_acc.append([m, train_acc, test_acc])

RFC_model = RandomForestClassifier(n_estimators=rfc_M, max_features=rfc_d, max_depth=rfc_m, random_state=0).fit(X_train, y_train)
train_acc = RFC_model.score(X_train, y_train)
test_acc = RFC_model.score(X_test, y_test)
m = 'Random Forest Classifier'
model_acc.append([m, train_acc, test_acc])

# %%
print("Feature importance: ")
np.array([X.columns.values.tolist(), list(DTC_model.feature_importances_)]).T
# Out:
# Feature importance:
# array([['meanfreq', '0.0'],
#        ['sd', '0.0'],
#        ['median', '0.0'],
#        ['Q25', '0.09374767307988444'],
#        ['Q75', '0.0'],
#        ['IQR', '0.08822289571362149'],
#        ['skew', '0.0'],
#        ['kurt', '0.0'],
#        ['sp.ent', '0.171609139997743'],
#        ['sfm', '0.0'],
#        ['mode', '0.23786692664598233'],
#        ['centroid', '0.054235891832641485'],
#        ['meanfun', '0.09320083650036289'],
#        ['minfun', '0.0'],
#        ['maxfun', '0.02968772045916739'],
#        ['meandom', '0.21747141357309113'],
#        ['mindom', '0.0'],
#        ['maxdom', '0.013957502197505868'],
#        ['dfrange', '0.0'],
#        ['modindx', '0.0']], dtype='<U32')

# %%
importances = DTC_model.feature_importances_
indices = np.argsort(importances)
plt.figure(figsize=(12,8))
plt.barh(range(len(indices)), importances[indices], align='center')
plt.yticks(range(len(indices)), df.columns[indices])
plt.title('Feature Importance')
# Out:
# Text(0.5, 1.0, 'Feature Importance')

# %%
print("Feature importance: ")
np.array([X.columns.values.tolist(), list(RFC_model.feature_importances_)]).T
# Out:
# Feature importance:
# array([['meanfreq', '0.025065684707905236'],
#        ['sd', '0.05872908598666551'],
#        ['median', '0.040751995626455664'],
#        ['Q25', '0.06531511679475521'],
#        ['Q75', '0.07414530764216808'],
#        ['IQR', '0.04425014303528579'],
#        ['skew', '0.030559785560584463'],
#        ['kurt', '0.043997443790153246'],
#        ['sp.ent', '0.05662630797087403'],
#        ['sfm', '0.06268214325503593'],
#        ['mode', '0.0658246815567297'],
#        ['centroid', '0.035743859839854696'],
#        ['meanfun', '0.06985646016418262'],
#        ['minfun', '0.044420997072775005'],
#        ['maxfun', '0.021879072314542846'],
#        ['meandom', '0.09471646711100216'],
#        ['mindom', '0.028687852403418163'],
#        ['maxdom', '0.055982831246792986'],
#        ['dfrange', '0.03613230511923392'],
#        ['modindx', '0.0446324588015848']], dtype='<U32')

# %%
importances = RFC_model.feature_importances_
indices = np.argsort(importances)
plt.figure(figsize=(12,8))
plt.barh(range(len(indices)), importances[indices], align='center')
plt.yticks(range(len(indices)), df.columns[indices])
plt.title('Feature Importance')
# Out:
# Text(0.5, 1.0, 'Feature Importance')

# %%
result = pd.DataFrame(model_acc, columns=['Model', 'Training Accuracy', 'Validation Accuracy'])
result[['Model', 'Training Accuracy', 'Validation Accuracy']]
# Out:
#                       Model  Training Accuracy  Validation Accuracy
# 0                       SVM           0.668135             0.583333
# 1  Decision Tree Classifier           0.646109             0.561404
# 2  Random Forest Classifier           0.992658             0.600877
